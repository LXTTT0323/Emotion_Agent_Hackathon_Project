# %%
import os
from openai import AzureOpenAI

endpoint = "https://emotionagentco1241584875.openai.azure.com/"
model_name = "gpt-4o-mini"
deployment = "gpt-4o-mini"

subscription_key = "2dZw8VQ9ZBXqd1yXpVO8pFyIYCe1JHsbPSt0Z0m6jJmHFOICEQF6JQQJ99BDACHYHv6XJ3w3AAAAACOGggHR"
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        }
    ],
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# Paris is a city rich in culture, history, and beauty, offering countless sights and experiences. Here are some must-see attractions and activities:
#
# ### Iconic Landmarks
# 1. **Eiffel Tower**: Visit this iconic symbol of Paris; consider going up for stunning views of the city.
# 2. **Louvre Museum**: Home to thousands of works of art, including the Mona Lisa and the Venus de Milo. Don't forget to explore the museum's beautiful architecture.
# 3. **Notre-Dame Cathedral**: Even post-fire, the cathedral remains a breathtaking site. Check out the exhibits nearby to learn more about its history and restoration.
# 4. **Sacré-Cœur Basilica**: Located in Montmartre, this basilica offers stunning views of Paris from its steps.
#
# ### Historic Neighborhoods
# 5. **Montmartre**: Wander through the artistic streets, visit the Place du Tertre, and enjoy a meal at a local café.
# 6. **Le Marais**: Explore this charming district filled with boutiques, galleries, and beautiful historic architecture.
#
# ### Cultural Institutions
# 7. **Musée d'Orsay**: Home to an extensive collection of Impressionist and Post-Impressionist masterpieces.
# 8. **Palace of Versailles**: A short trip from Paris, this opulent palace and its gardens are a must-see.
#
# ### Parks and Gardens
# 9. **Luxembourg Gardens**: A beautiful park where you can relax, stroll, or enjoy a picnic.
# 10. **Tuileries Garden**: Located between the Louvre and Place de la Concorde, it's a perfect spot for a leisurely walk.
#
# ### Unique Experiences
# 11. **Seine River Cruise**: Consider a boat cruise for a unique perspective of the city's landmarks.
# 12. **Latin Quarter**: Known for its vibrant street life, cafes, and bookstores, it’s also home to the Sorbonne University and the Panthéon.
# 13. **Pompidou Center**: A modern architectural marvel housing a vast collection of contemporary art.
#
# ### Culinary Delights
# 14. **Try Traditional French Cuisine**: Don't miss trying authentic croissants, escargot, coq au vin, and pastries at local bistros and patisseries.
# 15. **Visit a Local Market**: Explore markets like Marché Bastille or Marché des Enfants Rouges for fresh produce and local delicacies.
#
# ### Nightlife
# 16. **Enjoy a Cabaret Show**: Catch a show at the Moulin Rouge or a smaller venue for a lively night out.
#
# ### Other Suggestions
# 17. **Sainte-Chapelle**: Known for its stunning stained-glass windows, it’s a hidden gem located near Notre-Dame.
# 18. **Arc de Triomphe and Champs-Élysées**: Climb to the top for another great view and then stroll down one of the most famous streets in the world.
#
# When planning your visit, check the local events and exhibitions that might be happening during your stay to enhance your experience. Enjoy your trip to Paris!

# %%
import os
from openai import AzureOpenAI

endpoint = "https://emotionagentco1241584875.openai.azure.com/"
model_name = "gpt-4o-mini"
deployment = "gpt-4o-mini"

subscription_key = "2dZw8VQ9ZBXqd1yXpVO8pFyIYCe1JHsbPSt0Z0m6jJmHFOICEQF6JQQJ99BDACHYHv6XJ3w3AAAAACOGggHR"
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    stream=True,
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        },
        {
            "role": "assistant",
            "content": "Paris, the capital of France, is known for its stunning architecture, art museums, historical landmarks, and romantic atmosphere. Here are some of the top attractions to see in Paris:\n \n 1. The Eiffel Tower: The iconic Eiffel Tower is one of the most recognizable landmarks in the world and offers breathtaking views of the city.\n 2. The Louvre Museum: The Louvre is one of the world's largest and most famous museums, housing an impressive collection of art and artifacts, including the Mona Lisa.\n 3. Notre-Dame Cathedral: This beautiful cathedral is one of the most famous landmarks in Paris and is known for its Gothic architecture and stunning stained glass windows.\n \n These are just a few of the many attractions that Paris has to offer. With so much to see and do, it's no wonder that Paris is one of the most popular tourist destinations in the world.",
        },
        {
            "role": "user",
            "content": "What is so great about #1?",
        }
    ],
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment
)

for update in response:
    if update.choices:
        print(update.choices[0].delta.content or "", end="")

client.close()
# Out:
# The Eiffel Tower, ranked as one of the top attractions in Paris, is celebrated for several reasons:
#
# 1. **Iconic Status**: The Eiffel Tower is arguably the most recognizable structure in the world, symbolizing Paris and France. Its silhouette is iconic and is often associated with romance and elegance.
#
# 2. **Architectural Marvel**: Designed by Gustave Eiffel and completed in 1889, the tower was an engineering feat of its time, showcasing innovative iron structure techniques. It stands 1,083 feet tall (330 meters) and was the tallest man-made structure in the world until the completion of the Chrysler Building in New York in 1930.
#
# 3. **Stunning Views**: Visitors can ascend the tower to various levels, each offering breathtaking panoramic views of Paris. From the summit, you can see landmarks like the Seine River, Notre-Dame, the Louvre, and Montmartre.
#
# 4. **Illumination**: The Eiffel Tower is beautifully illuminated at night, often sparkling with lights every hour on the hour, creating a magical atmosphere. The sight of it lit up against the night sky is unforgettable.
#
# 5. **Cultural Significance**: The tower has become a symbol of art, culture, and history, representing not just Paris but the spirit of innovation and romance associated with France.
#
# 6. **Public Spaces**: The areas around the Eiffel Tower, including the Champ de Mars and the Trocadéro Gardens, are great for picnicking, photography, and enjoying a leisurely stroll, offering great spots to view the tower itself.
#
# 7. **Dining Options**: The tower houses several restaurants, including the 58 Tour Eiffel and Le Jules Verne, which provide a unique dining experience with exceptional views.
#
# 8. **Historic Events**: Over the years, the Eiffel Tower has been the site of various significant events and celebrations, adding to its historical importance.
#
# Overall, visiting the Eiffel Tower is more than just seeing a landmark; it's about experiencing the history, beauty, and culture of Paris all in one place.
